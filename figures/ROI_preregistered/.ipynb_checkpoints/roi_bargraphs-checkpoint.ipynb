# %%
import pandas as pd
import numpy as np
import math
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
roi = pd.read_csv('Fam-HC_MentPPI_roiresults.csv')

# %%
roi.head()
# Out:
#     DEPMENT   FAMMENT    HCMENT   DEPRAND   FAMRAND    HCRAND
# 0 -0.002714 -0.099048  0.129171 -0.002714  0.084716  0.007396
# 1 -0.065110  0.034984  0.099038 -0.065110  0.046685 -0.172280
# 2 -0.017248  0.043905 -0.032108 -0.017248 -0.016195 -0.100833
# 3  0.244721 -0.119358 -0.049261  0.244721  0.043599 -0.008045
# 4 -0.122502  0.026263 -0.086916 -0.122502  0.036075 -0.134761

# %%
fam_ment_avg = roi["FAMMENT"].mean()
fam_ment_std = roi["FAMMENT"].std()
fam_ment_se = (fam_ment_std)/(math.sqrt(130))

dep_ment_avg = roi["DEPMENT"].mean()
dep_ment_std = roi["DEPMENT"].std()
dep_ment_se = (dep_ment_std)/(math.sqrt(71))

hc_ment_avg = roi["HCMENT"].mean()
hc_ment_std = roi["HCMENT"].std()
hc_ment_se = (hc_ment_std)/(math.sqrt(105))

fam_rand_avg = roi["FAMRAND"].mean()
fam_rand_std = roi["FAMRAND"].std()
fam_rand_se = (fam_rand_std)/(math.sqrt(103))

dep_rand_avg = roi["DEPRAND"].mean()
dep_rand_std = roi["DEPRAND"].std()
dep_rand_se = dep_rand_std/(math.sqrt(71))

hc_rand_avg = roi["HCRAND"].mean()
hc_rand_std = roi["HCRAND"].std()
hc_rand_se = hc_rand_std/math.sqrt(105)

# %%
print('Mental_PPI Data:')
print('fam_ment_avg=',fam_ment_avg,'dep_ment_avg=',dep_ment_avg,'hc_ment_avg=',hc_ment_avg)
print('fam_ment_se=',fam_ment_se,'dep_ment_se=',dep_ment_se,'hc_ment_se=',hc_ment_se)
print('')
print('Random_PPI Data:')
print('fam_rand_avg=',fam_rand_avg,'dep_rand_avg=',dep_rand_avg,'hc_rand_avg=',hc_rand_avg)
print('fam_rand_se=',fam_rand_se,'dep_rand_se=',dep_rand_se,'hc_rand_se=',hc_rand_se)
# Out:
# Mental_PPI Data:
# fam_ment_avg= 0.010943515093203883 dep_ment_avg= -0.01362529135633803 hc_ment_avg= -0.03866278410476192
# fam_ment_se= 0.0065766388192016936 dep_ment_se= 0.0096467082386286 hc_ment_se= 0.00860301170193473
#
# Random_PPI Data:
# fam_rand_avg= 0.00043987292718446636 dep_rand_avg= -0.01362529135633803 hc_rand_avg= -0.02726114119428572
# fam_rand_se= 0.008583508509839225 dep_rand_se= 0.0096467082386286 hc_rand_se= 0.008485810256015632

# %%
# data to plot
n_groups = 3 #depresion, family history, then HCs
#need to change to HC, Depression, FAM
#change again to hc fam dep
mental_means = (hc_ment_avg,fam_ment_avg,dep_ment_avg)
random_means = (hc_rand_avg,fam_rand_avg,dep_rand_avg)

# create plot
fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.35
opacity = 0.55

mentalbars = plt.bar(index, mental_means, bar_width,
alpha=opacity,
color='b',
yerr=(hc_ment_se,fam_ment_se,dep_ment_se),
capsize=4,
label='Ment')

randombars = plt.bar(index + bar_width, random_means, bar_width,
alpha=opacity,
color='purple',
yerr=(hc_rand_se,fam_rand_se,dep_rand_se),
capsize=4,
label='Rand')

plt.xlabel('Group')
plt.ylabel('Timecourse')
plt.title('ROI Data')
plt.xticks(index + bar_width-0.2, ('HC', 'Fam', 'Dep'))
plt.legend()
plt.axhline(linewidth=1, color='black')

plt.tight_layout()
plt.show()

# %%
#saving a plain figure as an SVG
# %config InlineBackend.figure_format = 'svg'

# data to plot
n_groups = 3 #HC, family history, then depression
#need to change to HC, Depression, FAM
mental_means = (hc_ment_avg,fam_ment_avg,dep_ment_avg)
random_means = (hc_rand_avg,fam_rand_avg,dep_rand_avg)

# create plot
fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.35
opacity = 1

mentalbars = plt.bar(index, mental_means, bar_width,
alpha=opacity,
color='b',
edgecolor='black',
yerr=(hc_ment_se,fam_ment_se,dep_ment_se),
capsize=4,
label='Ment')

randombars = plt.bar(index + bar_width, random_means, bar_width,
alpha=opacity,
color='purple',
edgecolor='black',
yerr=(hc_rand_se,fam_rand_se,dep_rand_se),
capsize=4,
label='Rand')

#ax.set_yticklabels([])
plt.xticks(index + bar_width-0.2, ('', '', ''))
plt.axhline(linewidth=1, color='black')

#plt.savefig("Fam-HC_MentPPI_roiresults.svg",format='svg', transparent=True)

plt.show()

# %%
#New Left Crus 7b ROI Display for RAND results

rand_df = pd.read_csv('leftcrus7b_roiresults.csv')

# %%
rand_df.head()
# Out:
#    DEP_RAND  FAM_RAND   HC_RAND  DEP_MENT  FAM_MENT   HC_MENT
# 0 -0.051185  0.100074  0.027845 -0.032988  0.076761  0.054664
# 1  0.043861  0.024591 -0.216829 -0.005299  0.017281  0.147920
# 2 -0.044448 -0.028103  0.089910 -0.004734  0.058416  0.179725
# 3  0.054687  0.051608 -0.049463 -0.072506  0.126622 -0.025657
# 4 -0.236199 -0.016814  0.032727 -0.125710 -0.064932  0.058355

# %%
# %config InlineBackend.figure_format = 'svg'

# data to plot
n_groups = 3 # HC, DEP, FAM
mental_means = (rand_df["HC_MENT"].mean(),rand_df["FAM_MENT"].mean(),rand_df["DEP_MENT"].mean())
random_means = (rand_df["HC_RAND"].mean(), rand_df["FAM_RAND"].mean(), rand_df["DEP_RAND"].mean())

# create plot
fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.35
opacity = .55

mentalbars = plt.bar(index, mental_means, bar_width,
alpha=opacity,
edgecolor="#000000",
linewidth=1,
color='b',
yerr=(rand_df["HC_MENT"].std()/math.sqrt(105), rand_df["FAM_MENT"].std()/math.sqrt(103),rand_df["DEP_MENT"].std()/math.sqrt(71)),
capsize=4,
label='Ment')

randombars = plt.bar(index + bar_width, random_means, bar_width,
alpha=opacity,
edgecolor="#000000",
linewidth=1,
color='purple',
yerr=(rand_df["HC_RAND"].std()/math.sqrt(105), rand_df["FAM_RAND"].std()/math.sqrt(103),rand_df["DEP_RAND"].std()/math.sqrt(71)),
capsize=4,
label='Rand')

plt.xlabel('Group')
plt.ylabel('Timecourse')
plt.title('ROI Data')
plt.xticks(index + bar_width-0.2, ('HC', 'FAM', 'DEP'))
plt.legend()
plt.axhline(linewidth=1, color='black')

plt.tight_layout()
plt.show()

# %%
# %config InlineBackend.figure_format = 'svg'

# data to plot
n_groups = 3 # HC, DEP, FAM
mental_means = (rand_df["HC_MENT"].mean(),rand_df["FAM_MENT"].mean(),rand_df["DEP_MENT"].mean())
random_means = (rand_df["HC_RAND"].mean(), rand_df["FAM_RAND"].mean(), rand_df["DEP_RAND"].mean())

# create plot
fig, ax = plt.subplots()
index = np.arange(n_groups)
bar_width = 0.35
opacity = 1

mentalbars = plt.bar(index, mental_means, bar_width,
alpha=opacity,
edgecolor="#000000",
linewidth=1,
color='b',
yerr=(rand_df["HC_MENT"].std()/math.sqrt(105), rand_df["FAM_MENT"].std()/math.sqrt(103),rand_df["DEP_MENT"].std()/math.sqrt(71)),
capsize=4,
label='Ment')

randombars = plt.bar(index + bar_width, random_means, bar_width,
alpha=opacity,
edgecolor="#000000",
linewidth=1,
color='purple',
yerr=(rand_df["HC_RAND"].std()/math.sqrt(105), rand_df["FAM_RAND"].std()/math.sqrt(103),rand_df["DEP_RAND"].std()/math.sqrt(71)),
capsize=4,
label='Rand')

plt.axhline(linewidth=1, color='black')
plt.tight_layout()
ax.set_yticklabels([])
plt.xticks(index + bar_width-0.2, ('', '', ''))

plt.axhline(linewidth=1, color='black')

plt.savefig("results_roi_crus7b.svg",format='svg', transparent=True)
plt.show()
